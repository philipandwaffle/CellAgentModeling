# %%
# for x in range(2,16,2):
#     for y in range(2,24,2):
#         print("{{\"x\": {}, \"y\": {}, \"z\": 1}},".format(x,y))

for x in range(2,49,2):
    for y in range(46,49,2):
        print("{{\"x\": {}, \"y\": {}, \"z\": 0}},".format(x,y))

# for x in range(2,16,2):
#     for y in range(28,49,2):
#         print("{{\"x\": {}, \"y\": {}, \"z\": 1}},".format(x,y))

# for x in range(36,49,2):
#     for y in range(28,49,2):
#         print("{{\"x\": {}, \"y\": {}, \"z\": 1}},".format(x,y))

# {"x": 2,"y": 2,"z": 1},
# Out:
# {"x": 2, "y": 46, "z": 0},
# {"x": 2, "y": 48, "z": 0},
# {"x": 4, "y": 46, "z": 0},
# {"x": 4, "y": 48, "z": 0},
# {"x": 6, "y": 46, "z": 0},
# {"x": 6, "y": 48, "z": 0},
# {"x": 8, "y": 46, "z": 0},
# {"x": 8, "y": 48, "z": 0},
# {"x": 10, "y": 46, "z": 0},
# {"x": 10, "y": 48, "z": 0},
# {"x": 12, "y": 46, "z": 0},
# {"x": 12, "y": 48, "z": 0},
# {"x": 14, "y": 46, "z": 0},
# {"x": 14, "y": 48, "z": 0},
# {"x": 16, "y": 46, "z": 0},
# {"x": 16, "y": 48, "z": 0},
# {"x": 18, "y": 46, "z": 0},
# {"x": 18, "y": 48, "z": 0},
# {"x": 20, "y": 46, "z": 0},
# {"x": 20, "y": 48, "z": 0},
# {"x": 22, "y": 46, "z": 0},
# {"x": 22, "y": 48, "z": 0},
# {"x": 24, "y": 46, "z": 0},
# {"x": 24, "y": 48, "z": 0},
# {"x": 26, "y": 46, "z": 0},
# {"x": 26, "y": 48, "z": 0},
# {"x": 28, "y": 46, "z": 0},
# {"x": 28, "y": 48, "z": 0},
# {"x": 30, "y": 46, "z": 0},
# {"x": 30, "y": 48, "z": 0},
# {"x": 32, "y": 46, "z": 0},
# {"x": 32, "y": 48, "z": 0},
# {"x": 34, "y": 46, "z": 0},
# ...

# %%
for i in range(1,25,1):
    print(i*(1/25))
# Out:
# 0.04
# 0.08
# 0.12
# 0.16
# 0.2
# 0.24
# 0.28
# 0.32
# 0.36
# 0.4
# 0.44
# 0.48
# 0.52
# 0.56
# 0.6
# 0.64
# 0.68
# 0.72
# 0.76
# 0.8
# 0.84
# 0.88
# 0.92
# 0.96
